# %% [markdown]
# # Milestone 1
# Building on previous exercises, build an interactive application that asks the user a series of questions and then stores the user's answers for later analysis.

# %% [markdown]
# ## Requirements
# Your submission should include the following:
# - A Chatbot that asks three users a series of at least three questions.
# - Your chatbot should store the user's responses in a data structure, preferably a Pandas DataFrame, so that it can present a graphical analysis of the responses.
# - Your chatbot should provide at least one visualization, such as a vertical bar chart, that provides a basic summary and analysis of the user input.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ### Create a chatbot that can ask three questions

# %%
def Chatbot1():
    
    positive = list(pd.read_csv("positive_words.txt", header=0).iloc[:,0].values)
    negative = list(pd.read_csv("negative_words.txt", header=0).iloc[:,0].values)

    positive_responses = ["I am happy to hear that!", "I am so proud of you!", "I am so happy for you!"]
    negative_responses = ["I am sorry to hear that!", "I hope you get better", "I can understand! Go out and bask in the sun when you have time!"]
    neutral_responses = ["I see!", "Ok!"]
    
    ## TODO: The chatbot asks the first question
    print("[Koala] Hi! My name is Koala. I'm a warmful assistance.")
    print("[Koala] What is your name? You can also type \"Bye\" to turn me off.")
    user_name = input("[Koala] What is your name? You can also type \"Bye\" to turn me off.")
    print("[You]", user_name)
    if (user_name.lower() == "bye"):
        print("[Koala] Good Bye!")
        return 
    
    ## TODO: The chatbot asks the second question
    print("[Koala] Hi " + user_name + "! How are you feeling now? ")
    user_feeling_input = input("Hi " + user_name + "! How are you feeling now? ")
    if (user_feeling_input.lower() == "bye"):
        print("[Koala] Good Bye!")
        return
    print("[You]", user_feeling_input)
    positive_word_count = len(set(user_feeling_input.lower().split(" ")).intersection(set(positive)))
    negative_word_count = len(set(user_feeling_input.lower().split(" ")).intersection(set(negative)))
    if positive_word_count > negative_word_count:
        print("[Koala]", random.choice(positive_responses))
    elif positive_word_count < negative_word_count:
        print("[Koala]",random.choice(negative_responses))
    else:
        print("[Koala]",random.choice(neutral_responses))

    ## TODO: The chatbot asks the third question
    print("[Koala] " + user_name + ", now please give me the given numbers a, b, and c. I can help you generate ax^2 + bx + c graphics.")
    a, b, c = input("[Koala] Please give me the given numbers a, b, and c. For example, type \"1 2 3\" and press enter.").split(" ")
    print("[You]", a, b, c)
    print("[Koala] Did you just type: a = " + a + ", b = " + b + ", c = " + c + "?")
    user_input = input("[Koala] Did you just type: a = " + a + ", b = " + b + ", c = " + c + "? (Yes/No)")
    print("[You]", user_input)
    if (user_input.lower() == "bye"):
        print("[Koala] Good Bye!")
        return
    while (user_input.lower() != "yes"): 
        print("[Koala] I see. " + user_name + ", please give me the given numbers a, b, and c. I can help you generate ax^2 + bx + c graphics.")
        a, b, c = input("[Koala] Please give me the given numbers a, b, and c. For example, type \"1 2 3\" and press enter.").split(" ")
        print("[You]", a, b, c)
        print("[Koala] Did you just type: a = " + a + ", b = " + b + ", c = " + c + "?")
        user_input = input("Did you just type: a = " + a + ", b = " + b + ", c = " + c + "? (Yes/No)")
        print("[You]", user_input)
    a, b, c = float(a), float(b), float(c)
    print("[Koala] OK! Let us see. Here are the graph for you :D")
    x = np.arange(-15, 15, 1)
    y = a*(x**2) + b*x + c 
    plt.plot(x, y)
    plt.title("Quadratic Function")
    plt.xlabel("Values of x")
    plt.ylabel("Values of y")
    plt.show()

Chatbot1()
# Out:
# [Koala] Hi! My name is Koala. I'm a warmful assistance.
# [Koala] What is your name? You can also type "Bye" to turn me off.
# [You] Joe
# [Koala] Hi Joe! How are you feeling now?
# [You] Good
# [Koala] I am so proud of you!
# [Koala] Joe, now please give me the given numbers a, b, and c. I can help you generate ax^2 + bx + c graphics.
# [You] 2 3 4
# [Koala] Did you just type: a = 2, b = 3, c = 4?
# [You] yes
# [Koala] OK! Let us see. Here are the graph for you :D

# %% [markdown]
# ### Enhance the chatbot to make it store data and summarize data

# %%
def Chatbot2():

    ## TODO: The chatbot asks the first question
    print("[Koala] Hi! My name is Koala. I'm a warmful assistance.")
    print("[Koala] What is your name? You can also type \"Bye\" to turn me off.")
    user_name = input("[Koala] What is your name? You can also type \"Bye\" to turn me off.")
    print("[You]", user_name)
    if (user_name.lower() == "bye"):
        print("[Koala] Good Bye!")
        return False

    ## TODO: The chatbot asks the second question
    positive = list(pd.read_csv("positive_words.txt", header=0).iloc[:,0].values)
    negative = list(pd.read_csv("negative_words.txt", header=0).iloc[:,0].values)
    positive_responses = ["I am happy to hear that!", "I am so proud of you!", "I am so happy for you!"]
    negative_responses = ["I am sorry to hear that!", "I hope you get better!", "I can understand! Go out and bask in the sun when you have time!"]
    neutral_responses = ["I see!", "Ok!"]
    print("[Koala] Hi " + user_name + "! How are you feeling now? ")
    user_feeling_input = input("Hi " + user_name + "! How are you feeling now? ")
    if (user_feeling_input.lower() == "bye"):
        print("[Koala] Good Bye!")
        return False
    print("[You]", user_feeling_input)
    positive_word_count = len(set(user_feeling_input.lower().split(" ")).intersection(set(positive)))
    negative_word_count = len(set(user_feeling_input.lower().split(" ")).intersection(set(negative)))
    if positive_word_count > negative_word_count:
        user_mood = "positive"
        print("[Koala]", random.choice(positive_responses))
    elif positive_word_count < negative_word_count:
        user_mood = "negative"
        print("[Koala]",random.choice(negative_responses))
    else:
        user_mood = "neutral"
        print("[Koala]",random.choice(neutral_responses))

    ## TODO: The chatbot asks the third question
    print("[Koala] " + user_name + ", now please give me the given numbers a, b, and c. I can help you generate ax^2 + bx + c graphics.")
    a, b, c = input("[Koala] Please give me the given numbers a, b, and c. For example, type \"1 2 3\" and press enter.").split(" ")
    print("[You]", a, b, c)
    print("[Koala] Did you just type: a = " + a + ", b = " + b + ", c = " + c + "?")
    user_input = input("[Koala] Did you just type: a = " + a + ", b = " + b + ", c = " + c + "? (Yes/No)")
    if (user_input.lower() == "bye"):
        print("[Koala] Good Bye!")
        return False
    while (user_input.lower() != "yes"): 
        print("[You]", user_input)
        print("[Koala] OK! I see. " + user_name + ", please give me the given numbers a, b, and c. I can help you generate ax^2 + bx + c graphics.")
        a, b, c = input("Please give me the given numbers a, b, and c. For example, type \"1 2 3\" and press enter.").split(" ")
        print("[You]", a, b, c)
        print("[Koala] Did you just type: a = " + a + ", b = " + b + ", c = " + c + "?")
        user_input = input("Did you just type: a = " + a + ", b = " + b + ", c = " + c + "? (Yes/No)")        
    print("[You]", user_input)
    a, b, c = float(a), float(b), float(c)
    print("[Koala] OK! Let us see. Here are the graph for you :D")
    x = np.arange(-15, 15, 1)
    y = a*(x**2) + b*x + c 
    plt.plot(x, y)
    plt.title("Quadratic Function")
    plt.xlabel("Values of x")
    plt.ylabel("Values of y")
    plt.show()
    
    ## TODO: The chatbot stores user data
    try:
        historical_data = pd.read_csv("historical_data.csv", index_col = 0)
    except: 
        historical_data = pd.DataFrame()

    new_response = pd.DataFrame({"user name": user_name, "mood": user_mood, "a": a, "b": b, "c": c}, index=[len(historical_data)])
    historical_data = pd.concat([historical_data, new_response])
    historical_data.reset_index()
    historical_data.to_csv("historical_data.csv")

    return True

user_count = 0
switch = True
while switch:
    if user_count >= 3:
        print("[Koala] I have chated with", user_count, "users. Do you still want to talk? (Yes/No)")
        user_input = input("[Koala] Do you still want to talk? (Yes/No or Bye)")
        print("[You]", user_input)
        while (user_input.lower() != "yes" and user_input.lower() != "no" and user_input.lower() != "bye"):
            print("[Koala] Sorry. Do you still want to talk? (Yes/No)")
            user_input = input("[Koala] Sorry. Do you still want to talk? (Yes/No)")
        if user_input.lower() == "no" or user_input.lower() == "bye": 
            print("[Koala] Good Bye!")
            break
        switch = Chatbot2()
        if switch == False:
            break
        else:
            user_count += 1 
    else: 
        switch = Chatbot2()
        if switch == False:
            break
        else:
            user_count += 1
# Out:
# [Koala] Hi! My name is Koala. I'm a warmful assistance.
# [Koala] What is your name? You can also type "Bye" to turn me off.
# [You] Uncle
# [Koala] Hi Uncle! How are you feeling now?
# [You] OK
# [Koala] Ok!
# [Koala] Uncle, now please give me the given numbers a, b, and c. I can help you generate ax^2 + bx + c graphics.
# [You] 2 5 8
# [Koala] Did you just type: a = 2, b = 5, c = 8?
# [You] yes
# [Koala] OK! Let us see. Here are the graph for you :D
# [Koala] Hi! My name is Koala. I'm a warmful assistance.
# [Koala] What is your name? You can also type "Bye" to turn me off.
# [You] Andy
# [Koala] Hi Andy! How are you feeling now?
# [You] Alright
# [Koala] Ok!
# [Koala] Andy, now please give me the given numbers a, b, and c. I can help you generate ax^2 + bx + c graphics.
# [You] 1 2 5
# [Koala] Did you just type: a = 1, b = 2, c = 5?
# [You] yes
# [Koala] OK! Let us see. Here are the graph for you :D
# [Koala] Hi! My name is Koala. I'm a warmful assistance.
# ...

# %%
try:
    historical_data = pd.read_csv("historical_data.csv", index_col = 0)
except: 
    historical_data = pd.DataFrame()

historical_data
# Out:
#     user name      mood     a     b     c
# 0         Joe  positive   1.0   2.0   3.0
# 1       Kelly   neutral   2.0   4.0   8.0
# 2        John  negative  10.0  20.0  30.0
# 3      Claire  positive  15.0  30.0  45.0
# 4       Bella  positive   4.0  12.0  24.0
# 5       Jacky   neutral  20.0  40.0  80.0
# 6        Judy  negative  13.0  17.0  19.0
# 7       Kitty  positive   2.0   8.0  16.0
# 8   Butterfly  positive  11.0  22.0  33.0
# 9       Uncle   neutral   2.0   5.0   8.0
# 10       Andy   neutral   1.0   2.0   5.0
# 11  Yorkshire  positive   1.0   2.0   8.0

# %%
print("[Koala] OK! Let's check the mood stats of the people I'm talking to.")
num_of_positive = historical_data["mood"].value_counts()["positive"]
num_of_neutral = historical_data["mood"].value_counts()["neutral"]
num_of_negative = historical_data["mood"].value_counts()["negative"]

bar_chart = pd.DataFrame({'User Mood':['Positive', 'Neutral', 'Negative'], 'Number of People':[num_of_positive, num_of_neutral, num_of_negative]})
bar_chart.plot.bar(x = 'User Mood', y = 'Number of People', rot = 0)
# Out:
# [Koala] OK! Let's check the mood stats of the people I'm talking to.
# <AxesSubplot:xlabel='User Mood'>

# %%
print("[Koala] Let's show all the graphs of the quadratic equation that I helped draw.")
for index, row in historical_data.iterrows():
    x = np.arange(-15, 15, 1)
    y = row["a"]*(x**2) + row["b"]*x + row["c"] 
    plt.plot(x, y)
    plt.title(row["user name"] + "'s Quadratic Function: " + str(row["a"]) + "x^2 + " + str(row["b"]) + "x + " + str(row["c"]))
    plt.xlabel("Values of x")
    plt.ylabel("Values of y")
    plt.show()
# Out:
# [Koala] Let's show all the graphs of the quadratic equation that I helped draw.
